# %% [markdown]
# <a href="https://colab.research.google.com/github/taniokah/DL-Basic-Seminar/blob/master/OpenCV_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OpenCVテスト

# %%
# %matplotlib inline
import cv2 #　opencvのインポート
import matplotlib.pyplot as plt # matplotlib(描画用)

print(cv2.__version__)
# Out:
# 3.4.3

# %%
img=cv2.imread("data/train/cats/cat.0.jpg")

show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(show_img) #表示

# %%
# !pip install pytube
# !pip install ffmpeg

# %%
from pytube import YouTube

yt = YouTube("https://www.youtube.com/watch?v=ZvFNaUWLj9Y")
yt.streams.first().download()
# Out:
# '/content/20190217 徳島大学医学部 vs 吉野クラブ 2nd No2.mp4'

# %%
import cv2

#動画ファイルを読み込む
file_name = u"20190217 徳島大学医学部 vs 吉野クラブ 2nd No2.mp4"
video = cv2.VideoCapture(file_name)

#フレーム数を取得
frame_count = int(video.get(7))

#フレームレート(1フレームの時間単位はミリ秒)の取得
frame_rate = int(video.get(5))

dir_name = "screen_caps"

print(frame_count)
for i in range(frame_count):
  _, frame = video.read()
  #cv2.imwrite(dir_name+ "/" + str(i) + ".png", frame)
  #file_name = dir_name+ "/" + str(i) + ".png"
  file_name = "/" + str(i) + ".png"
  cv2.imwrite(dir_name+ "/" + str(i) + ".png", frame)
# Out:
# 1919

# %%
# %matplotlib inline
import cv2 #　opencvのインポート
import matplotlib.pyplot as plt # matplotlib(描画用)

#for i in range(frame_count):
for i in range(10):
  file_name = "/" + str(i) + ".png"
  img = cv2.imread(file_name)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.figure(figsize=(100, 100), dpi=80)
  plt.subplot(10, 1, i + 1)
  plt.imshow(show_img) #表示
